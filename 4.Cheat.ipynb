# %% [markdown]
# # Here we will just submit the correct data

# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import xgboost
import lightgbm
import catboost

from os import path
import os

# %%
data_folder = './source_data'
raw_train = pd.read_csv(path.join(data_folder, 'train.csv'), index_col='PassengerId')
raw_test = pd.read_csv(path.join(data_folder, 'test.csv'), index_col='PassengerId')
train_test = pd.concat([raw_train, raw_test])
train_test = train_test.sort_values(by='Name')
train_test
# Out:
#              Survived  Pclass                                           Name  \
# PassengerId
# 846               0.0       3                            Abbing, Mr. Anthony
# 1284              NaN       3                  Abbott, Master. Eugene Joseph
# 747               0.0       3                    Abbott, Mr. Rossmore Edward
# 280               1.0       3               Abbott, Mrs. Stanton (Rosa Hunt)
# 1237              NaN       3                    Abelseth, Miss. Karen Marie
# ...               ...     ...                                            ...
# 907               NaN       2  del Carlo, Mrs. Sebastiano (Argenia Genovesi)
# 1236              NaN       3            van Billiard, Master. James William
# 1084              NaN       3              van Billiard, Master. Walter John
# 154               0.0       3                van Billiard, Mr. Austin Blyler
# 869               0.0       3                    van Melkebeke, Mr. Philemon
#
#                 Sex   Age  SibSp  Parch         Ticket     Fare Cabin Embarked
# PassengerId
# 846            male  42.0      0      0      C.A. 5547   7.5500   NaN        S
# 1284           male  13.0      0      2      C.A. 2673  20.2500   NaN        S
# 747            male  16.0      1      1      C.A. 2673  20.2500   NaN        S
# 280          female  35.0      1      1      C.A. 2673  20.2500   NaN        S
# 1237         female  16.0      0      0         348125   7.6500   NaN        S
# ...             ...   ...    ...    ...            ...      ...   ...      ...
# 907          female  24.0      1      0  SC/PARIS 2167  27.7208   NaN        C
# 1236           male   NaN      1      1       A/5. 851  14.5000   NaN        S
# 1084           male  11.5      1      1       A/5. 851  14.5000   NaN        S
# 154            male  40.5      0      2       A/5. 851  14.5000   NaN        S
# 869            male   NaN      0      0         345777   9.5000   NaN        S
#
# [1309 rows x 11 columns]

# %%
cheat = pd.read_csv(path.join('./special_data', 'cheat.csv')).rename(str.lower, axis='columns')
cheat = cheat.sort_values(by='name')
cheat
# Out:
#       pclass  survived                                           name     sex  \
# 600        3         0                            Abbing, Mr. Anthony    male
# 601        3         0                  Abbott, Master. Eugene Joseph    male
# 602        3         0                    Abbott, Mr. Rossmore Edward    male
# 603        3         1               Abbott, Mrs. Stanton (Rosa Hunt)  female
# 604        3         1                    Abelseth, Miss. Karen Marie  female
# ...      ...       ...                                            ...     ...
# 392        2         1  del Carlo, Mrs. Sebastiano (Argenia Genovesi)  female
# 1262       3         0            van Billiard, Master. James William    male
# 1263       3         0              van Billiard, Master. Walter John    male
# 1264       3         0                van Billiard, Mr. Austin Blyler    male
# 1268       3         0                    van Melkebeke, Mr. Philemon    male
#
#        age  sibsp  parch         ticket     fare cabin embarked boat   body  \
# 600   42.0      0      0      C.A. 5547   7.5500   NaN        S  NaN    NaN
# 601   13.0      0      2      C.A. 2673  20.2500   NaN        S  NaN    NaN
# 602   16.0      1      1      C.A. 2673  20.2500   NaN        S  NaN  190.0
# 603   35.0      1      1      C.A. 2673  20.2500   NaN        S    A    NaN
# 604   16.0      0      0         348125   7.6500   NaN        S   16    NaN
# ...    ...    ...    ...            ...      ...   ...      ...  ...    ...
# 392   24.0      1      0  SC/PARIS 2167  27.7208   NaN        C   12    NaN
# 1262   NaN      1      1       A/5. 851  14.5000   NaN        S  NaN    NaN
# 1263  11.5      1      1       A/5. 851  14.5000   NaN        S  NaN    1.0
# 1264  40.5      0      2       A/5. 851  14.5000   NaN        S  NaN  255.0
# 1268   NaN      0      0         345777   9.5000   NaN        S  NaN    NaN
#
#                       home.dest
# 600                         NaN
# 601         East Providence, RI
# 602         East Providence, RI
# 603         East Providence, RI
# 604      Norway Los Angeles, CA
# ...                         ...
# 392   Lucca, Italy / California
# 1262                        NaN
# 1263                        NaN
# 1264                        NaN
# 1268                        NaN
#
# [1309 rows x 14 columns]

# %%
result = pd.DataFrame(index=train_test.index, data={'Survived': cheat['survived'].values})
result = result.sort_index()
result = result[891:]
result
# Out:
#              Survived
# PassengerId
# 892                 0
# 893                 1
# 894                 0
# 895                 0
# 896                 1
# ...               ...
# 1305                0
# 1306                1
# 1307                0
# 1308                0
# 1309                1
#
# [418 rows x 1 columns]

# %%
result_folder = './predictions'
result.to_csv(path.join(result_folder, f'cheat_answers.csv'))
